# %% [markdown]
# <img alt="bruno logo" width="15%" src="https://raw.githubusercontent.com/brunobonatini/Data_Science/main/logo.png">
#
# #### **Data Scientist & Analyst**
# *by [Bruno Bonatini](https://www.linkedin.com/in/bsbonatini/)*
#
# ---

# %% [markdown]
# # Panorama do COVID-19 no Brasil e no Mundo
#
# <center><img alt="Colaboratory logo" width="100%" src='https://raw.githubusercontent.com/brunobonatini/Data_Science/main/Projeto_Covid19/covid_intro.jpg'></center>
#
# COVID-19 é uma doença infecciosa causada pelo vírus SARS-Cov-2, identificada pela primeira vez em dezembro de 2019 na cidade de Wuhan, na China, com um surto de pneumonia por causa desconhecida. Houve relatos que as pessoas infectadas tiveram contatos com animais em um mercado de frutos do mar e animais vivos na cidade, mas não foi confirmado que o vírus tenha sido transmitido por estes animais.
#
# Em Janeiro de 2020, o vírus se espalhou rapidamente em outras partes da China e depois para outros países, quando em Março de 2020 foi decretada pela OMS (Organização Mundial da Saúde) como pandemia global.
#
# Transmitido principalmente por meio de gotículas provenientes de tosses ou espirros de pessoas infectadas, a gravidade dos sintomas varia muito de pessoa para pessoa, mas podem incluir febre, tosse seca, fadiga, dor de cabeça, perda de olfato ou paladar, dor de garganta, dores musculares e dificuldades na respiração. Em casos mais graves, a doença pode levar a pneumonia, falência de orgãos e até a morte.
#
# <img alt="Colaboratory logo" width="80%" src="https://raw.githubusercontent.com/brunobonatini/Data_Science/main/Projeto_Covid19/covid19.jpg">
#
# Desde o início da pandemia, a COVID-19 afetou milhões de pessoas em todo o mundo e teve um impacto significativo na saúde pública, economia e na sociedade como um todo.
#
# Após alguns meses de pesquisas, as vacinas foram liberadas no mês Dezembro de 2020, tornando-se uma medida muito importante para controlar a proliferação da doença.
#
# Mesmo após a liberação das vacinas, notou-se um aumento de casos principalmente em épocas de festas e datas comemorativas, fazendo com que o vírus sofresse mutações gerando novas variantes e consequentemente novas doses de vacinas.
#
# Neste **projeto** farei a análise da COVID-19 de uma maneira geral sobre os casos de infecções, mortes e vacinas no Brasil e no Mundo, para assim conseguir extrair alguns insights importantes dos dados.

# %% [markdown]
# ## Obtenção dos Dados
#
# Os dados utilizados neste projeto foram obtidos através de uma fonte super segura e confiável no [GitHub](https://github.com/owid/covid-19-data/tree/master/public/data), que extraiu-os diretamente do site [Our World in Data](https://ourworldindata.org/).
#
# Este dataset é de grande volume de dados, os mesmo coletados desde o início da pandemia até o momento, sendo atualizado a cada semana.
#
# A grande dificuldade de se analisar dados de uma nova doença como a COVID-19 é que há muitas incertezas em relação ao vírus.
#
# Além de ser uma doença relativamente nova e altamente contagiosa, os sistemas de saúde não dão conta da quantidade de pacientes infectados e que precisam de tratamento, os cientistas precisam coletar dados em tempo real para analisar e entender a natureza da doença e os sistemas governamentais, estaduais e federais, divulgam informações diferentes de acordo com o benefício próprio de cada um, gerando muita diferença nos números, muitas vezes por questões políticas.
#
# Caso tenham algum problema em baixar o arquivo diretamente do repositório oficial, deixo aqui o [meu link](https://raw.githubusercontent.com/brunobonatini/Data_Science/main/Projeto_Covid19/owid-covid-data.csv) atualizado em 06.03.2023.
#
# ## Descrição das variáveis
#
# Como este dataset contém 67 variáveis no total, vou fazer a descrição apenas das variáveis que serão utilizadas neste projeto, para quem quiser ter o conhecimento completo com todas as variáveis, deixarei o [link oficial](https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-codebook.csv) com a descrição de cada uma detalhadamente para entendimento de todos.
#
# * iso_code - Código de identificação dos países
# * location - Localização geográfica dos países
# * date - Data de observação dos acontecimentos
# * total_cases - Número total de casos de COVID-19
# * new_cases - Novos casos de COVID-19
# * total_deaths - Número total de mortes pela COVID-19
# * new_deaths - Novas mortes por COVID-19
# * population - Número total populacional
# * people_vaccinated - Total de pessoas que receberam pelo menos uma dose da vacina contra a COVID-19
# * median_age - Média de idade da população
# * life_expectancy - Expectativa de vida das pessoas que nasceram em 2019

# %% [markdown]
# ## Importando as bibliotecas necessárias e o dataset para o desenvolvimento do Projeto

# %%
# importando as bibliotecas necessárias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# importando o dataset COVID-19 para um DataFrame
data = 'https://raw.githubusercontent.com/brunobonatini/Data_Science/main/Projeto_Covid19/owid-covid-data.csv'
df = pd.read_csv(data)

# %% [markdown]
# Após a importação das bibliotecas e leitura do dataset, visualizarei as primeiras e últimas  entradas e também o nome das colunas para ter um melhor entendimento dos dados que estão armazenados neste dataset.

# %%
# visualizando as primeiras entradas do dataset
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# visualizando as últimas entradas do dataset
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 261494      ZWE    Africa  Zimbabwe  2023-02-27     263921.0        0.0
# 261495      ZWE    Africa  Zimbabwe  2023-02-28     263921.0        0.0
# 261496      ZWE    Africa  Zimbabwe  2023-03-01     264127.0      206.0
# 261497      ZWE    Africa  Zimbabwe  2023-03-02     264127.0        NaN
# 261498      ZWE    Africa  Zimbabwe  2023-03-03     264127.0        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 261494              39.857        5663.0         0.0                0.143
# 261495              39.857        5663.0         0.0                0.143
# 261496              29.429        5668.0         5.0                0.714
# 261497                 NaN        5668.0         0.0                0.714
# 261498                 NaN        5668.0         0.0                0.714
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# visualizando o nome de todas as variáveis
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# <img alt="Colaboratory logo" width="80%" src="https://raw.githubusercontent.com/brunobonatini/Data_Science/main/Projeto_Covid19/covid_mundo.jpg">

# %% [markdown]
# ## 1.Análise Exploratória dos Dados
#
# Na análise exploratória dos dados, estaremos compreendendo o tamanho do dataset que será analisado, olharemos também quais são os tipos de dados das variáveis e qual a quantidade de valores ausente estão presentes na base de dados.

# %% [markdown]
# ### 1.1.Qual o volume do DataFrame? Quais os tipos de dados das variáveis?
#
# Logo abaixo, conseguimos ver a quantidade de entradas no dataset, a quantidade de colunas, seus valores não nulos e o tipo de dados de cada variável, fator muito importante para trabalharmos com os dados corretamente.
#
# O total de entrada é de 261.499 e o total de colunas é de 67.

# %%
# verificando o tamanho do dataframe, tipos de variáveis e valores não nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261499 entries, 0 to 261498
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    261499 non-null  object
#  1   continent                                   246824 non-null  object
#  2   location                                    261499 non-null  object
#  3   date                                        261499 non-null  object
#  4   total_cases                                 246951 non-null  float64
#  5   new_cases                                   246675 non-null  float64
#  6   new_cases_smoothed                          245471 non-null  float64
#  7   total_deaths                                227230 non-null  float64
#  8   new_deaths                                  227158 non-null  float64
# ...

# %%
print('Total de entradas: {}'.format(df.shape[0]))
print('Total de variáveis: {}'.format(df.shape[1]))
# Out:
# Total de entradas: 261499
# Total de variáveis: 67

# %% [markdown]
# ### 1.2.Qual a quantidade de valores ausentes presentes no dataset em relação ao total de entradas?
#
# Ao investigar os valores ausentes neste projeto, notei que muitas variáveis possuem mais de 90% dos dados ausentes e não serão utilizados para a análise. Neste caso não precisei dar uma atenção especial para estas colunas.
#
# Como estamos trabalhando com dados de uma doença que não era conhecida no início, acima podemos perceber que, algumas variáveis que estão com valores `NAN` pode ser devido ao fato de não existirem dados realmente, como por exemplo: `total de mortes`, `total de vacinas`, `total de casos confirmados`, demorou um certo período para começarem a registrar os acontecimentos, portanto nestes casos poderíamos preencher com o valor 0 estes valores ausentes.
#
# É muito importante conhecer primeiro a base de dados que estamos trabalhando, antes de tomarmos qualquer ação em relação aos dados, devemos pesquisar o porque está faltando dado em determinada coluna ou campo, pois qualquer alteração no dataset pode fazer com que sua análise seja prejudicada.

# %%
round((df.isnull().sum() / df.shape[0]).sort_values(ascending=False),2)
# Out:
# weekly_icu_admissions                      0.97
# weekly_icu_admissions_per_million          0.97
# excess_mortality_cumulative_per_million    0.97
# excess_mortality                           0.97
# excess_mortality_cumulative                0.97
#                                            ...
# total_cases                                0.06
# population                                 0.00
# date                                       0.00
# location                                   0.00
# iso_code                                   0.00
# Length: 67, dtype: float64

# %% [markdown]
# Outro detalhe importante que mencionei acima, é saber o tipo de dado de cada variável, principalmente das que farão parte da análise.
#
# Neste projeto consegui perceber que a variável `date`(data) está com o tipo de dado como `object`(string), e este tipo não é correto quando vamos trabalhar analisando datas.
#
# Por isso, visualizarei o tipo de dado de cada variável e alterarei o tipo da variável `date` de *`object`* para *`datetime`*.

# %%
# visualizando os tipos de dados de cada variável
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# population                                 float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %%
# alterando o tipo de dado da variável date
df['date'] = pd.to_datetime(df['date'])

# %%
# verificando a variável date
df['date']
# Out:
# 0        2020-02-24
# 1        2020-02-25
# 2        2020-02-26
# 3        2020-02-27
# 4        2020-02-28
#             ...
# 261494   2023-02-27
# 261495   2023-02-28
# 261496   2023-03-01
# 261497   2023-03-02
# 261498   2023-03-03
# Name: date, Length: 261499, dtype: datetime64[ns]

# %% [markdown]
# O tipo de dado da variável `date` foi alterado, podemos ver agora que está como `dtype: datetime64[ns]`.
#
# Com isso vou verificar qual é a data mais recente que temos neste dataset, pois será utilizada para tirar alguns insights mais adiante.

# %%
# verificando a data mais recente
df['date'].max()

print('A data mais recente que temos neste dataset é {}'.format(df['date'].max()))
# Out:
# A data mais recente que temos neste dataset é 2023-03-03 00:00:00

# %% [markdown]
# ### 1.3.Copiando as variáveis utilizadas para um novo DataFrame
#
# Como tenho um dataset com 67 colunas e não utilizarei todas elas, vou fazer uma cópia somente das colunas que vou analisar neste projeto, facilitando a compreensão e aumento a velocidade do processamento dos dados.
#
# Para fazer isso é preciso entender quais as perguntas do negócio eu preciso responder, e então, selecionar as variáveis corretas e assim ganhar tempo no processo de análise.
#
# Vou preencher os valores ausente com 0, pois como foi dito anteriormente, não se tinhamos casos, mortes e nem pessoas vacinadas quando a doença foi descoberta. Demorou-se um tempo para começarem a inserir dados sobre a doença, portanto, entendi que estes valores nulos podem ser realmente iguais a 0.

# %%
df_covid = df[['iso_code', 'location', 'date', 'total_cases', 
               'new_cases', 'total_deaths', 'new_deaths', 'population', 
               'people_vaccinated', 'median_age', 'life_expectancy']]

df_covid.fillna(0, inplace=True)
# Out:
# <ipython-input-12-9526b5c86820>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_covid.fillna(0, inplace=True)

# %%
# visualizando as primeiras entradas do novo dataset 
df_covid.head()
# Out:
#   iso_code     location       date  total_cases  new_cases  total_deaths  \
# 0      AFG  Afghanistan 2020-02-24          5.0        5.0           0.0
# 1      AFG  Afghanistan 2020-02-25          5.0        0.0           0.0
# 2      AFG  Afghanistan 2020-02-26          5.0        0.0           0.0
# 3      AFG  Afghanistan 2020-02-27          5.0        0.0           0.0
# 4      AFG  Afghanistan 2020-02-28          5.0        0.0           0.0
#
#    new_deaths  population  people_vaccinated  median_age  life_expectancy
# 0         0.0  41128772.0                0.0        18.6            64.83
# 1         0.0  41128772.0                0.0        18.6            64.83
# 2         0.0  41128772.0                0.0        18.6            64.83
# 3         0.0  41128772.0                0.0        18.6            64.83
# 4         0.0  41128772.0                0.0        18.6            64.83

# %%
# verificando o tipo do dataframe df_covid
type(df_covid)
# Out:
# pandas.core.frame.DataFrame

# %%
#visualizando os tipos de dados das variáveis
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261499 entries, 0 to 261498
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   iso_code           261499 non-null  object
#  1   location           261499 non-null  object
#  2   date               261499 non-null  datetime64[ns]
#  3   total_cases        261499 non-null  float64
#  4   new_cases          261499 non-null  float64
#  5   total_deaths       261499 non-null  float64
#  6   new_deaths         261499 non-null  float64
#  7   population         261499 non-null  float64
#  8   people_vaccinated  261499 non-null  float64
#  9   median_age         261499 non-null  float64
#  10  life_expectancy    261499 non-null  float64
# dtypes: datetime64[ns](1), float64(8), object(2)
# memory usage: 21.9+ MB

# %% [markdown]
# <img alt="Colaboratory logo" width="80%" src='https://raw.githubusercontent.com/brunobonatini/Data_Science/main/Projeto_Covid19/covid_analises.jpg'>

# %% [markdown]
# ## 2.Insights
#
# Insights são percepções e entendimentos que podem ser extraídos a partir da análise e visualização dos dados.
#
# Os insights podem incluir tendências, padrões, anomalias, relações de causa e efeito, etc., e serem utilizados para desenvolver estratégias de negócio, orientar campanhas, identificar oportunidades de crescimento e melhoramentos, prever resultados futuros e diversos outros objetivos.
#
# Neste projeto extrairemos alguns insights como:
#
# * Qual a localidade geográfica com maior número de casos e mortes?
# * Quais os países que mais tem casos de mortes no decorrer dos anos?
# * Quantas pessoas tomaram ao menos uma dose da vacina no mundo?
# * Qual foi a evolução da COVID-19 no mundo?
# * Qual a data da primeira morte no Brasil?
# * Quantos dias levou para ser registrado a primeira morte no Brasil, considerando o primeiro caso registrado?
# * Quantas pessoas tomaram ao menos uma dose da vacina no Brasil?
# * Qual a relação entre os casos totais e mortes totais no Brasil?

# %% [markdown]
# ### 2.1.Quais as regiões no mundo possuem mais casos e mortes de COVID-19?
#
# Nesta fase do projeto, vamos ter uma visão geral sobre qual região, geograficamente falando, foi mais afetada com a pandemia causada pela doença COVID-19.

# %%
## verificando os casos de COVID-19 atualmente por localidade geográfica em ordem decresente
data_atual_casos = df_covid.loc[df_covid['date'] == '2023-03-03'].sort_values(by='total_cases', ascending=False)[1:7]
data_atual_casos
# Out:
#         iso_code             location       date  total_cases  new_cases  \
# 101933  OWID_HIC          High income 2023-03-03  431389174.0   146087.0
# 76217   OWID_EUR               Europe 2023-03-03  248178623.0    74670.0
# 13263   OWID_ASI                 Asia 2023-03-03  210624451.0    24148.0
# 77353   OWID_EUN       European Union 2023-03-03  184034010.0    59157.0
# 248894  OWID_UMC  Upper middle income 2023-03-03  144939552.0    36049.0
# 171042  OWID_NAM        North America 2023-03-03  122518346.0    61046.0
#
#         total_deaths  new_deaths    population  people_vaccinated  median_age  \
# 101933     2874278.0      1109.0  1.250515e+09       9.980905e+08         0.0
# 76217      2034753.0       565.0  7.448078e+08       5.226358e+08         0.0
# 13263      1623045.0       101.0  4.721383e+09       3.666338e+09         0.0
# 77353      1214967.0       519.0  4.501468e+08       3.381802e+08         0.0
# ...

# %% [markdown]
# Sobre as regiões pelo mundo que mais tem casos registrados da COVID-19:
#
# * Na primeira posição aparece os países de alta-renda com 431.389.174 casos, pode ser por serem países mais populosos
# * A Europa é a região com mais casos registrados, totalizando 248.178.623 casos
# * A Ásia é a segunda região com mais casos de COVID-19, totalizando 210.624.451 casos
# * A América do Norte, formada por apenas 3 países, Estados Unidos, Canadá e México, vem em terceiro lugar com 122.518.346 casos

# %%
## verificando as mortes de COVID-19 atualmente por localidade geográfica em ordem decresente
data_atual_casos = df_covid.loc[df_covid['date'] == '2023-03-03'].sort_values(by='total_deaths', ascending=False)[1:6]
data_atual_casos
# Out:
#         iso_code             location       date  total_cases  new_cases  \
# 101933  OWID_HIC          High income 2023-03-03  431389174.0   146087.0
# 248894  OWID_UMC  Upper middle income 2023-03-03  144939552.0    36049.0
# 76217   OWID_EUR               Europe 2023-03-03  248178623.0    74670.0
# 13263   OWID_ASI                 Asia 2023-03-03  210624451.0    24148.0
# 171042  OWID_NAM        North America 2023-03-03  122518346.0    61046.0
#
#         total_deaths  new_deaths    population  people_vaccinated  median_age  \
# 101933     2874278.0      1109.0  1.250515e+09       9.980905e+08         0.0
# 248894     2608261.0       146.0  2.525921e+09       2.108099e+09         0.0
# 76217      2034753.0       565.0  7.448078e+08       5.226358e+08         0.0
# 13263      1623045.0       101.0  4.721383e+09       3.666338e+09         0.0
# 171042     1586062.0       503.0  6.003237e+08       4.592122e+08         0.0
#
#         life_expectancy
# 101933              0.0
# ...

# %% [markdown]
# Falando de mortes por COVID-19 no mundo:
#
# * A Europa é a região que mais teve mortes pela COVID-19, totalizando 2.034.753 de mortes
# * A Ásias fica em segundo lugar no número de mortes, 1.623.045
# * A América do Norte, vem em terceiro no ranking, com 1.586.062 mortes, lembrando que que está região é composta por apenas 3 países, Estados Unidos, Canadá e México

# %% [markdown]
# ### 2.2.Considerando a data atual, quais os países com mais casos e mortes?
#
# Veremos então como estão os casos de mortes por COVID-19 considerando a data mais atual deste dataset, que é 03.03.2023, lembrando que este dataset pode ter sua data atual alterada para mais recente no arquivo oficial.

# %%
# verificando os casos de COVID-19 atualmente por países em ordem decresente
data_atual_casos = df_covid.loc[df_covid['date'] == '2023-03-03'].sort_values(by='total_cases', ascending=False)[7:14]
data_atual_casos
# Out:
#         iso_code             location       date  total_cases  new_cases  \
# 246939       USA        United States 2023-03-03  103643742.0    60103.0
# 137342  OWID_LMC  Lower middle income 2023-03-03   97155299.0     1666.0
# 217966  OWID_SAM        South America 2023-03-03   67948143.0    22842.0
# 107482       IND                India 2023-03-03   44688722.0      334.0
# 82906        FRA               France 2023-03-03   39674247.0     3194.0
# 88393        DEU              Germany 2023-03-03   38210850.0     8279.0
# 32932        BRA               Brazil 2023-03-03   37081209.0    17745.0
#
#         total_deaths  new_deaths    population  people_vaccinated  median_age  \
# 246939     1122157.0       490.0  3.382899e+08       0.000000e+00        38.3
# 137342     1346059.0        22.0  3.432097e+09       2.245056e+09         0.0
# 217966     1350193.0       107.0  4.368167e+08       3.748590e+08         0.0
# ...

# %% [markdown]
# Quando tratamos de casos de COVID-19 registrados até o momento por país, podemos afirmar que:
#
# * Os Estados Unidos lidera o ranking com 103.643.742 casos
# * O Brasil é o quinto país com mais casos registrados, 37.081.209 casos
# * Quem aparece em segundo lugar com maior número de casos é a Índia, 44.688.722 casos

# %%
# verificando os casos de mortes atualmente por países em ordem decrescente
data_atual_mortes = df_covid.loc[df_covid['date'] == '2023-03-03'].sort_values(by='total_deaths', ascending=False)[9:14]
data_atual_mortes
# Out:
#        iso_code       location       date  total_cases  new_cases  \
# 246939      USA  United States 2023-03-03  103643742.0    60103.0
# 32932       BRA         Brazil 2023-03-03   37081209.0    17745.0
# 107482      IND          India 2023-03-03   44688722.0      334.0
# 193947      RUS         Russia 2023-03-03   22002485.0    14375.0
# 150482      MEX         Mexico 2023-03-03    7459860.0        0.0
#
#         total_deaths  new_deaths    population  people_vaccinated  median_age  \
# 246939     1122157.0       490.0  3.382899e+08       0.000000e+00        38.3
# 32932       699276.0        79.0  2.153135e+08       1.893937e+08        33.5
# 107482      530775.0         3.0  1.417173e+09       1.027377e+09        28.2
# 193947      388240.0        39.0  1.447133e+08       0.000000e+00        39.6
# 150482      333038.0         0.0  1.275041e+08       0.000000e+00        29.3
#
#         life_expectancy
# 246939            78.86
# 32932             75.88
# ...

# %% [markdown]
# Se tratando da quantidades de mortes por país, até a data de 03 de Março de 2023:
#
# * Os Estados Unidos aparece em primeiro lugar no ranking com 1.122.157 mortes
# * O Brasil vem em segundo lugar com 699.276 mortes
# * Em terceiro lugar com maior número de mortes está a Índia com 530.775 mortes
#
# Dado importante é que, a Índia é o segundo país com maior número de casos registrados, porém, em número de mortes fica atrás do Brasil que é o quinto país em número de casos.
#
# Ou seja, morre mais pessoas no Brasil com menor quantidade de casos do que na Índia.
#
# Para que a gente possa visualizar melhor os resultados de mortes, vou plotar um gráfico de barras.

# %%
# visualizando o total de mortes através de um gráfico de barras
data_atual_mortes10 = df_covid.loc[df_covid['date'] == '2023-03-03', ['location', 'total_deaths']].sort_values(by='total_deaths', ascending=False)[9:15]

data_atual_mortes10.plot(x='location', y='total_deaths', kind='bar', figsize=(10, 5), color='royalblue')
plt.title('Total de mortes - COVID-19')
plt.xlabel('Países')
plt.ylabel('Mortes')

plt.show();

# %% [markdown]
# ### 2.3.Quantas pessoas no Mundo receberam no mínimo a primeira dose da vacina?
#
# Agora vamos analisar quantas pessoas no mundo já foram vacinadas com pelo menos uma dose de vacina para COVID-19.

# %%
#visualzando os valores máximos da variável World 
df_covid.loc[df_covid['location'] == 'World'].max()
# Out:
# iso_code                        OWID_WRL
# location                           World
# date                 2023-03-03 00:00:00
# total_cases                  675806901.0
# new_cases                      4082893.0
# total_deaths                   6876591.0
# new_deaths                       60902.0
# population                  7975105024.0
# people_vaccinated           5557339852.0
# median_age                          30.9
# life_expectancy                    72.58
# dtype: object

# %%
#pessoas vacinadas no mundo em relação a população total
populacao_mundo = 7975105024
pessoas_vacinadas_mundo = 5557339852
total_vacinados_mundo = (pessoas_vacinadas_mundo / populacao_mundo) * 100

print('{:.2f} das pessoas no Mundo receberam no mínimo a primeira dose de vacina.'.format(total_vacinados_mundo))
# Out:
# 69.68 das pessoas no Mundo receberam no mínimo a primeira dose de vacina.

# %% [markdown]
# Após analisar os dados acima, chego a conclusão que aproximadamente 70% da população Mundial tomou pelo menos uma dose da vacina contra a COVID-19.

# %% [markdown]
# ### 2.4.Evolução do vírus pelo Mundo
#
# Uma das maiores áreas que se preocupa com a proliferação do vírus pelo mundo é a área da saúde. Mas não somente a área da saúde é afetada quando isso ocorre, toda área financeira e comercial de um país acaba entrando em crise com uma declaração de pandemia.

# %%
# plotando um gráfio de linhas 
df_covid.loc[df_covid['location'] == 'World', 'total_deaths'].reset_index(drop=True).plot(figsize=(10, 5));

# %% [markdown]
# Como podemos ver no gráfico, a progressão do vírus desde o seu descobrimento nunca parou de crescer até a data deste projeto, 03 de Março de 2023.
#
# Porém conforme as doses de vacinas foram sendo aplicadas, houve um maior controle nos casos de mortes. Não deixamos de pegar o vírus, apenas não estamos mais tendo complicações de saúde.

# %% [markdown]
# ## 3.Análise Exploratória para o Brasil
#
# Depois de analisar os casos da COVID-19 pelo Mundo, não poderia deixar de pegar uma carona e fazer uma análise da doença em meu país, o Brasil.

# %% [markdown]
# <img alt="Colaboratory logo" width="80%" src='https://raw.githubusercontent.com/brunobonatini/Data_Science/main/Projeto_Covid19/covid_brasil.jpg'>

# %% [markdown]
# Vou criar uma cópia do DataFrame da COVID-19 selecionando apenas o Brasil para poder trabalhar melhor com os dados.

# %%
# criando uma cópia do dataframe para o Brasil
df_brasil = df_covid[df['location'] == 'Brazil'].copy()

# visualizando as primeiras entradas do dataset para o Brasil
df_brasil.head()
# Out:
#       iso_code location       date  total_cases  new_cases  total_deaths  \
# 31831      BRA   Brazil 2020-02-26          1.0        1.0           0.0
# 31832      BRA   Brazil 2020-02-27          1.0        0.0           0.0
# 31833      BRA   Brazil 2020-02-28          1.0        0.0           0.0
# 31834      BRA   Brazil 2020-02-29          2.0        1.0           0.0
# 31835      BRA   Brazil 2020-03-01          2.0        0.0           0.0
#
#        new_deaths   population  people_vaccinated  median_age  life_expectancy
# 31831         0.0  215313504.0                0.0        33.5            75.88
# 31832         0.0  215313504.0                0.0        33.5            75.88
# 31833         0.0  215313504.0                0.0        33.5            75.88
# 31834         0.0  215313504.0                0.0        33.5            75.88
# 31835         0.0  215313504.0                0.0        33.5            75.88

# %%
# visualizando as últimas entradas do dataset para o Brasil
df_brasil.tail()
# Out:
#       iso_code location       date  total_cases  new_cases  total_deaths  \
# 32928      BRA   Brazil 2023-02-27   37038230.0    17699.0      699006.0
# 32929      BRA   Brazil 2023-02-28   37052936.0    14706.0      699087.0
# 32930      BRA   Brazil 2023-03-01   37063464.0    10528.0      699197.0
# 32931      BRA   Brazil 2023-03-02   37063464.0        0.0      699197.0
# 32932      BRA   Brazil 2023-03-03   37081209.0    17745.0      699276.0
#
#        new_deaths   population  people_vaccinated  median_age  life_expectancy
# 32928        78.0  215313504.0                0.0        33.5            75.88
# 32929        81.0  215313504.0        189377950.0        33.5            75.88
# 32930       110.0  215313504.0                0.0        33.5            75.88
# 32931         0.0  215313504.0        189385794.0        33.5            75.88
# 32932        79.0  215313504.0        189393744.0        33.5            75.88

# %% [markdown]
# ### 3.1. Identificando quando foi registrada a primeira morte no Brasil
#
# Acima consigo ver que a primeira data de registro para o Brasil foi 26.02.2020 e a última data de registro foi 03.03.2023.
#
# Agora preciso saber quando foi identificado o primeiro caso e primeira morte no Brasil, e qual o intervalo de dias demorou para a primeira morte ser identificada em relação ao primeiro caso.

# %%
# verificando quando foi registrado a primeira morte
df_brasil.loc[df_brasil['new_deaths'] != 0].head(1)
# Out:
#       iso_code location       date  total_cases  new_cases  total_deaths  \
# 31851      BRA   Brazil 2020-03-17        321.0      121.0           1.0
#
#        new_deaths   population  people_vaccinated  median_age  life_expectancy
# 31851         1.0  215313504.0                0.0        33.5            75.88

# %%
# verificando quando foi registrado o primeiro caso
df_brasil.loc[df_brasil['new_cases'] !=0].head(1)
# Out:
#       iso_code location       date  total_cases  new_cases  total_deaths  \
# 31831      BRA   Brazil 2020-02-26          1.0        1.0           0.0
#
#        new_deaths   population  people_vaccinated  median_age  life_expectancy
# 31831         0.0  215313504.0                0.0        33.5            75.88

# %%
# identificando quantos dias demorou para ser identificada a primeira morte em relação ao primeiro caso
from datetime import date

intervalo = df_brasil.date.loc[31851] - df_brasil.date.loc[31831]

print('Depois de {} do primeiro caso registrado, aconteceu a primeira morte.'.format(intervalo))
# Out:
# Depois de 20 days 00:00:00 do primeiro caso registrado, aconteceu a primeira morte.

# %% [markdown]
# De acordo com os dados, o Brasil demorou 20 dias para registrar a primeira morte no país após registrar o primeiro caso da doença.

# %% [markdown]
# ### 3.2.Quantas pessoas no Brasil receberam no mínimo a primeira dose da vacina?
#
# Um número muito importante para sabermos, é a quantidade de pessoas no Brasil que tomaram no mínimo a primeira dose da vacina em relação a quantidade total da população no país.
#
# Conseguimos identificar nos dados abaixo que aproximadamente 88% da população no Brasil já foi vacinada contra a COVID-19, concluindo que apenas 12% da população ainda não tomou nenhuma dose da vacina.

# %%
# verificando a quantidade de pessoas vacinadas no Brasil
df_brasil[['location', 'population', 'people_vaccinated']].groupby(['location', 'population']).max()
# Out:
#                       people_vaccinated
# location population
# Brazil   215313504.0        189393744.0

# %%
# relação da quantidade de pessoas que tomaram a vacina com a populaçao no Brasil
populacao = 215313504
pessoas_vacinadas = 189393744
total_vacinados = (pessoas_vacinadas / populacao) * 100

print('{:.2f} das pessoas no Brasil receberam no mínimo a primeira dose de vacina.'.format(total_vacinados))
# Out:
# 87.96 das pessoas no Brasil receberam no mínimo a primeira dose de vacina.

# %% [markdown]
# ## 4.Casos e Mortes no Brasil
#
# Um dado muito importante é saber quantas mortes aconteceram no país em relação ao número de casos registrados com a doença.
#
# Vamos ver como ficou a proporção de mortes para as pessoas infectadas.

# %%
# verificando os valores estatisticos totais do Brasil
df_brasil.max()
# Out:
# iso_code                             BRA
# location                          Brazil
# date                 2023-03-03 00:00:00
# total_cases                   37081209.0
# new_cases                       287149.0
# total_deaths                    699276.0
# new_deaths                        4148.0
# population                   215313504.0
# people_vaccinated            189393744.0
# median_age                          33.5
# life_expectancy                    75.88
# dtype: object

# %%
# calculando a porcentagem de mortes em relaçao aos casos
casos = 37081209
mortes = 699276
percent = (mortes / casos) * 100

print('A número de mortes pela Covid-19 no Brasil em relação aos casos ficou em {:.2f}%.'.format(percent))
# Out:
# A número de mortes pela Covid-19 no Brasil em relação aos casos ficou em 1.89%.

# %% [markdown]
# Quando olhamos para uma porcentagem de 1,89% de mortes em relação ao número de casos parece um valor irrisório, mas devemos levar em consideração que dentro deste valor existem aproximadamente 700.000 pessoas que foram mortas pela COVID-19, é um número muito significativo.
#
# * Casos de infecções: 37.081.209
# * Casos de mortes: 699.276
# * Percentual de mortes em relação ao casos: 1,89%

# %% [markdown]
# ## 5.Evolução do vírus no Brasil
#
# Nesta última etapa do projeto, vamos analisar através dos gráficos, como foi a evolução do vírus no Brasil para os casos de infecção e casos de mortes pela COVID-19.

# %%
# plotando os gráficos de casos e mortes em escalas linear e logarítmica
a = list(range(1102))
b = df_brasil['total_cases']
c = df_brasil['total_deaths']

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, figsize=(10, 5))
ax1.set_title('Casos de COVID-19 no Brasil')
ax1.set_xlabel('Dias')
ax1.set_ylabel('Casos')
ax1.plot(a, b)

ax2.set_title('Casos de COVID-19 no Brasil (escala logarítmica)')
ax2.set_xlabel('Dias')
ax2.set_ylabel('Casos')
ax2.set_yscale('log')
ax2.plot(a, b)

ax3.set_title('Casos de mortes no Brasil')
ax3.set_xlabel('Dias')
ax3.set_ylabel('Mortes')
ax3.plot(a, c)

ax4.set_title('Casos de mortes no Brasil (escala logarítmica)')
ax4.set_xlabel('Dias')
ax4.set_ylabel('Mortes')
ax4.set_yscale('log')
ax4.plot(a, c)

plt.tight_layout()

# %% [markdown]
# Podemos concluir analisando os gráficos acima, que para os casos de infecção da doença os número foram subindo aos poucos até atingirem o auge, com relação as mortes elas demoraram um pouco para atingir o pico, e quando atingiu se manteve em alta.

# %% [markdown]
# ## Conclusão
#
# Este projeto teve como objetivo analisar os dados de uma das doenças que mais impactaram o mundo e a que mais gerou mortes nos últimos anos, a COVID-19.
#
# Tive a oportunidade de conhecer um pouco mais sobre a doença e tirar valores importantes sobre os casos de infecções e mortes geradas em todo o mundo.
#
# Realizei a coleta dos dados de uma fonte muito confiável que atualiza estes dados diretamente do site da OMS (Organização Mundial da Saúde). Foi feita a descrição das variáveis utilizadas, análise exploratória e tratamento dos dados para otimização em minha análise. Utilizei gráficos para melhor visualização dos resultados analisados.
#
# Com relação aos insights que foram extraídos, deixo aqui a minha conclusão sobre a COVID-19:
# * A Europa é a região com mais casos e mais mortes por COVID-19 do mundo;
# * Os Estados Unidos é o país com mais casos e mortes pela COVID-19 no mundo;
# * O Brasil é o segundo país com mais mortes do mundo tendo aproximadamente 88% de sua população vacinada;
# * Aproximadamente 70% da população mundial foi vacinada com pelo menos uma dose de vacina, sendo 30% um número considerável de pessoas no mundo sem tomar nenhuma dose.
# * A quantidade de mortes dos Estados Unidos 1.122.157 é quase o valor total da América do Norte inteira 1.586.062, lembrando que os países que completam a América do Norte são Canadá e México.
# * A primeira morte registrada no Brasil por COVID-19 foi em 17.03.2020, após 20 dias do primeiro caso registrado.
# * 1.89% das pessoas no Brasil morreram em relação ao total de casos registrados, número equivalente a aproximadamente 700.000 pessoas.
#
# Devido ao dataset ser imenso, outras análises e insights poderão ser extraídos e ficarão para um futuro projeto.
